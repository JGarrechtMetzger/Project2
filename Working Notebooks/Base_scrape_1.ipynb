# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests

# %% [markdown]
# # Website URL list construction

# %%
## The 'target_url' is the homepage of the target website
## The 'url_prefix' is the specific URL you use to append with the
## for-loop below.

target_url = 'https://sfbay.craigslist.org'
url_prefix = 'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s='

pages = ['120','240','360','480','600','720','840',
         '960','1080','1200','1320','1440','1560','1680',
         '1800','1920','2040','2160','2280','2400','2520',
         '2640','2760','2880','3000']
        
## This tests to make sure the URL list compiler is working
## on 3 pages.
# pages = ['120', '240', '360']

url_list = []

## This loop takes the base URL and adds just the string from the
## 'pages' object above so that each 'url' that goes into the
## 'url_list' is in the correct step of 120 results.

for page in pages:
    url = url_prefix + page
    url_list.append(url)

# %%
## This prints the 'url_list' as a QC check.

url_list
# Out:
# ['https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=120',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=240',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=360',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=480',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=600',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=720',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=840',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=960',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1080',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1200',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1320',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1440',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1560',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1680',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1800',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=1920',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2040',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2160',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2280',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2400',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2520',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2640',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2760',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=2880',
#  'https://sfbay.craigslist.org/d/musical-instruments/search/msa?s=3000']

# %% [markdown]
# # Scraping for-loop
#
# * This is what I'm calling a "dynamic" scraping function.  It's dynamic in the sense that it collects and defines the html as objects in real time.
# * Another method would be what I'm calling "static" scraping where the output from the 'url in url_list' for-loop is put into a list outside of the function with the entirity of the url's html.  The scraping then happens to a static object.
# * Choose ** **ONE** ** approach: Dynamic or Static

# %% [markdown]
# ## The "dynamic" method

# %%
''' 
                            ****NOTE****
The two empty lists 'df_list' and 'each_html_output' will
need to be empty. Therefore, make sure to restart the kernal before
running this cell.

'''

df_list = []
each_html_output = []

def attribute_scraping(starting_url):
    
    """ 
    These are the 5 attributes I am scraping from Craigslist. Any
    additional pieces of information to be made into objects will
    require 
    
        * adding an empty list
        
        *an additional for-loop or if statement depending on the find 
            target
        
        * adding to the dictionary at the end of the this function
        
        * adding to the print statement set at the end of this function
    """
    
    has_pics_bool = []
    price = []
    just_titles = []
    HOOD_list = []
    just_posted_datetimes = []
    
    """
    Parameters
    ----------
    response = requests.get(url)
        * This makes a request to the URL and returns a status code
        
    page = response.text
        * the html text (str object) from the 'get(url)'
        
    soup = BeautifulSoup(page, 'html.parser')
        * makes a BeautifulSoup object called 'page'
        * utilizes the parser designated in quotes as the second
            input of the method
            
    results = soup.find_all('li', class_='result-row')
        * returns an element ResultSet object.
        * this is the html text that was isolated from using the 
            'find()' or 'find_all()' methods.
        * 'li' is an html list tag.
        * 'class_' is the designator for a class attribute.
            - Here this corresponds with the 'result_row' class 
    
    """
    for url in url_list:
        response = requests.get(url)
        page = response.text
        soup = BeautifulSoup(page, 'html.parser')
        results = soup.find_all('li', class_='result-row')
      
        for res in results:
            """PRICE"""
            ## Loop for finding PRICE for a single page of 120 results
            p = res.find('span', class_='result-price').text
            price.append(p)

            """PICS"""
            ## Loop for finding the boolean HAS PICS of a single page of 
            ## 120 results. This tests whether >=1 picture is an attribute
            ## of the post.
            if res.find('span', class_='pictag') is None:
                has_pics_bool.append("False")
            else:
                has_pics_bool.append('True')


            """NEIGHBORHOOD"""
            ## Loop for finding NEIGHBORHOOD name for a single page of 120
            ## results.  This includes the drop down menu choices on
            ## Craigslist as well as the manually entered neighborhoods.
            if res.find('span', class_="result-hood") is None:
                HOOD_list.append("NONE")
            else:    
                h = res.find('span', class_="result-hood").text
                HOOD_list.append(h)

        """TITLE"""    
        ## Loop for finding TITLE for a single page of 120 results   
        titles=soup.find_all('a', class_="result-title hdrlnk")
        for title in titles:
            just_titles.append(title.text) 

        """DATETIME"""
        ## Loop for finding DATETIME for a single page of 120 results   
        posted_datetimes=soup.find_all(class_='result-date')
        for posted_datetime in posted_datetimes:
            if posted_datetime.has_attr('datetime'):
                just_posted_datetimes.append(posted_datetime['datetime'])       
    
    # Compilation dictionary of for-loop results       
    comp_dict = {'price': price, 
                'pics': has_pics_bool,
                'hood': HOOD_list,
                'title': just_titles,
                'datetimes': just_posted_datetimes}

          
    return comp_dict

    print(len(price))
    print(len(has_pics_bool))
    print(len(HOOD_list))
    print(len(just_titles))
    print(len(just_posted_datetimes))

# %% [markdown]
# Run the function and check the output dictionary.

# %%
base_dict = attribute_scraping(target_url)
base_dict
# Out:
# {'price': ['$950',
#   '$250',
#   '$350',
#   '$0',
#   '$4,500',
#   '$0',
#   '$200',
#   '$0',
#   '$80',
#   '$3,975',
#   '$125',
#   '$200',
#   '$900',
#   '$225',
#   '$375',
#   '$245',
#   '$100',
#   '$7,500',
#   '$50',
#   '$750',
#   '$200',
#   '$300',
#   '$129',
#   '$1,100',
#   '$3,600',
#   '$55',
#   '$150',
#   '$699',
#   '$0',
#   '$350',
#   '$80',
#   '$80',
#   '$65',
#   '$500',
#   '$50',
#   '$295',
#   '$100',
#   '$1,200',
#   '$450',
#   '$30',
#   '$150',
#   '$70',
#   '$750',
#   '$2,000',
#   '$575',
#   '$140',
#   '$120',
#   '$100',
#   '$40',
#   '$30',
#   '$110',
#   '$140',
#   '$60',
#   '$2,000',
#   '$20',
#   '$1,000',
#   '$200',
#   '$250',
#   '$120',
#   '$50',
#   '$120',
#   '$240',
#   '$400',
#   '$220',
#   '$1,800',
#   '$40',
#   '$75',
#   '$45',
#   '$85',
#   '$1,600',
#   '$450',
#   '$150',
#   '$400',
#   '$220',
#   '$575',
#   '$1,850',
#   '$350',
#   '$800',
#   '$750',
#   '$100',
#   '$37',
#   '$2,150',
#   '$115',
#   '$2,350',
#   '$65',
#   '$10',
#   '$775',
#   '$925',
#   '$1,550',
#   '$25',
#   '$295',
#   '$95',
#   '$95',
#   '$125',
#   '$3,300',
#   '$4,995',
#   '$80',
#   '$450',
#   '$120',
#   '$0',
#   '$90',
#   '$10',
#   '$20',
#   '$250',
#   '$800',
#   '$250',
#   '$700',
#   '$100',
#   '$925',
#   '$555',
#   '$800',
#   '$1,250',
#   '$525',
#   '$300',
#   '$700',
#   '$1,199',
#   '$400',
#   '$800',
#   '$495',
#   '$1,350',
#   '$600',
#   '$150',
#   '$1',
#   '$500',
#   '$800',
#   '$75',
#   '$150',
#   '$240',
#   '$150',
#   '$1,850',
#   '$1,850',
#   '$1,100',
#   '$0',
#   '$80',
#   '$40',
#   '$50',
#   '$0',
#   '$0',
#   '$3,000',
#   '$3,700',
#   '$160',
#   '$200',
#   '$115',
#   '$345',
#   '$0',
#   '$0',
#   '$45',
#   '$50',
#   '$450',
#   '$100',
#   '$225',
#   '$410',
#   '$1,300',
#   '$450',
#   '$500',
#   '$550',
#   '$50',
#   '$100',
#   '$699',
#   '$35',
#   '$3,500',
#   '$150',
#   '$350',
#   '$70',
#   '$1,500',
#   '$0',
#   '$0',
#   '$60',
#   '$80',
#   '$30',
#   '$100',
#   '$80',
#   '$200',
#   '$120',
#   '$60',
#   '$65',
#   '$180',
#   '$125',
#   '$300',
#   '$650',
#   '$2,000',
#   '$150',
#   '$5,500',
#   '$40',
#   '$500',
#   '$875',
#   '$350',
#   '$115',
#   '$75',
#   '$200',
#   '$45',
#   '$45',
#   '$1',
#   '$75',
#   '$380',
#   '$240',
#   '$300',
#   '$7,850',
#   '$300',
#   '$650',
#   '$1,200',
#   '$850',
#   '$60',
#   '$195',
#   '$1,125',
#   '$400',
#   '$0',
#   '$350',
#   '$3,200',
#   '$400',
#   '$120',
#   '$70',
#   '$90',
#   '$45',
#   '$250',
#   '$900',
#   '$49',
#   '$500',
#   '$250',
#   '$150',
#   '$80',
#   '$100',
#   '$20',
#   '$1',
#   '$1,250',
#   '$55',
#   '$550',
#   '$200',
#   '$40',
#   '$400',
#   '$100',
#   '$550',
#   '$60',
#   '$750',
#   '$350',
#   '$500',
#   '$145',
#   '$650',
#   '$0',
#   '$175',
#   '$145',
#   '$650',
#   '$0',
#   '$175',
#   '$125',
#   '$150',
#   '$1,600',
#   '$300',
#   '$400',
#   '$160',
#   '$999',
#   '$100',
#   '$300',
#   '$100',
#   '$75',
#   '$1,500',
#   '$500',
#   '$700',
#   '$1',
#   '$1,400',
#   '$80',
#   '$60',
#   '$1',
#   '$0',
#   '$1',
#   '$799',
#   '$1',
#   '$6,500',
#   '$325',
#   '$80',
#   '$100',
#   '$600',
#   '$800',
#   '$325',
#   '$195',
#   '$140',
#   '$240',
#   '$1,499',
#   '$400',
#   '$700',
#   '$350',
#   '$100',
#   '$175',
#   '$1',
#   '$5',
#   '$550',
#   '$500',
#   '$800',
#   '$1',
#   '$1',
#   '$65',
#   '$8,500',
#   '$1,750',
#   '$90',
#   '$125',
#   '$199',
#   '$50',
#   '$7,500',
#   '$80',
#   '$1',
#   '$3,300',
#   '$400',
#   '$85',
#   '$300',
#   '$120',
#   '$200',
#   '$400',
#   '$1,500',
#   '$300',
#   '$100',
#   '$700',
#   '$150',
#   '$150',
#   '$75',
#   '$700',
#   '$399',
#   '$80',
#   '$40',
#   '$150',
#   '$80',
#   '$40',
#   '$3,500',
#   '$1,000',
#   '$475',
#   '$450',
#   '$350',
#   '$800',
#   '$20',
#   '$75',
#   '$149',
#   '$250',
#   '$500',
#   '$3,000',
#   '$80',
#   '$300',
#   '$125',
#   '$400',
#   '$0',
#   '$1,850',
#   '$200',
#   '$625',
#   '$215',
#   '$110',
#   '$60',
#   '$450',
#   '$250',
#   '$160',
#   '$25',
#   '$40',
#   '$3,500',
#   '$200',
#   '$1,800',
#   '$90',
#   '$1,900',
#   '$1,500',
#   '$500',
#   '$299',
#   '$25',
#   '$200',
#   '$200',
#   '$150',
#   '$225',
#   '$450',
#   '$650',
#   '$375',
#   '$850',
#   '$4,400',
#   '$199',
#   '$125',
#   '$150',
#   '$1,800',
#   '$1,000',
#   '$450',
#   '$150',
#   '$17,995',
#   '$400',
#   '$200',
#   '$985',
#   '$1,000,000',
#   '$120',
#   '$20',
#   '$120',
#   '$750',
#   '$400',
#   '$7,500',
#   '$560',
#   '$699',
#   '$99',
#   '$240',
#   '$1',
#   '$0',
#   '$1',
#   '$399',
#   '$20',
#   '$89',
#   '$3,800',
#   '$249',
#   '$3,800',
#   '$2,000',
#   '$0',
#   '$265',
#   '$120',
#   '$1',
#   '$400',
#   '$200',
#   '$350',
#   '$1,500',
#   '$450',
#   '$449',
#   '$150',
#   '$100',
#   '$400',
#   '$30',
#   '$80',
#   '$1,300',
#   '$70',
#   '$100',
#   '$535',
#   '$100',
#   '$50',
#   '$500',
#   '$450',
#   '$200',
#   '$600',
#   '$40',
#   '$850',
#   '$70',
#   '$100',
#   '$40',
#   '$0',
#   '$60',
#   '$30',
#   '$70',
#   '$4,000',
#   '$300',
#   '$1,400',
#   '$60',
#   '$250',
#   '$350',
#   '$250',
#   '$300',
#   '$300',
#   '$450',
#   '$800',
#   '$900',
#   '$40',
#   '$0',
#   '$260',
#   '$95',
#   '$1',
#   '$1,250',
#   '$225',
#   '$200',
#   '$99',
#   '$0',
#   '$300',
#   '$400',
#   '$20',
#   '$95',
#   '$60',
#   '$150',
#   '$275',
#   '$100',
#   '$20',
#   '$5',
#   '$150',
#   '$60',
#   '$1,100',
#   '$80',
#   '$270',
#   '$120',
#   '$1,850',
#   '$1,500',
#   '$80',
#   '$10',
#   '$5',
#   '$250',
#   '$100',
#   '$0',
#   '$3,700',
#   '$2,000',
#   '$2,100',
#   '$7',
#   '$365',
#   '$225',
#   '$3',
#   '$60',
#   '$25',
#   '$255',
#   '$1,499',
#   '$100',
#   '$380',
#   '$5',
#   '$2,900',
#   '$10',
#   '$250',
#   '$0',
#   '$599',
#   '$20',
#   '$0',
#   '$90',
#   '$115',
#   '$874',
#   '$115',
#   '$25',
#   '$125',
#   '$60',
#   '$5',
#   '$30',
#   '$10',
#   '$200',
#   '$350',
#   '$299',
#   '$1',
#   '$280',
#   '$1,200',
#   '$375',
#   '$100',
#   '$12',
#   '$374',
#   '$16',
#   '$900',
#   '$3,200',
#   '$10',
#   '$600',
#   '$350',
#   '$300',
#   '$149',
#   '$1,100',
#   '$499',
#   '$299',
#   '$400',
#   '$160',
#   '$100',
#   '$450',
#   '$280',
#   '$5',
#   '$321',
#   '$2',
#   '$1',
#   '$400',
#   '$225',
#   '$20',
#   '$1',
#   '$7',
#   '$450',
#   '$20',
#   '$2',
#   '$375',
#   '$200',
#   '$60',
#   '$400',
#   '$20',
#   '$6',
#   '$6,000',
#   '$1,650',
#   '$1,500',
#   '$1,499',
#   '$2',
#   '$75',
#   '$249',
#   '$0',
#   '$250',
#   '$165',
#   '$6',
#   '$2,700',
#   '$70',
#   '$150',
#   '$800',
#   '$250',
#   '$319',
#   '$60',
#   '$20',
#   '$60',
#   '$500',
#   '$300',
#   '$550',
#   '$500',
#   '$325',
#   '$480',
#   '$320',
#   '$900',
#   '$1,500',
#   '$60',
#   '$20',
#   '$0',
#   '$0',
#   '$475',
#   '$275',
#   '$100',
#   '$160',
#   '$115',
#   '$115',
#   '$350',
#   '$10,000',
#   '$20',
#   '$375',
#   '$200',
#   '$1,200',
#   '$300',
#   '$800',
#   '$500',
#   '$20',
#   '$1,500',
#   '$700',
#   '$300',
#   '$300',
#   '$1,400',
#   '$500',
#   '$50',
#   '$3,400',
#   '$325',
#   '$300',
#   '$300',
#   '$1,200',
#   '$260',
#   '$80',
#   '$950',
#   '$80',
#   '$200',
#   '$175',
#   '$80',
#   '$75',
#   '$750',
#   '$400',
#   '$225',
#   '$100',
#   '$80',
#   '$100',
#   '$175',
#   '$200',
#   '$85',
#   '$300',
#   '$115',
#   '$110',
#   '$0',
#   '$60',
#   '$400',
#   '$15',
#   '$175',
#   '$0',
#   '$50',
#   '$120',
#   '$60',
#   '$90',
#   '$30',
#   '$900',
#   '$250',
#   '$11,500',
#   '$3',
#   '$650',
#   '$1',
#   '$4,000',
#   '$200',
#   '$3,500',
#   '$400',
#   '$1',
#   '$2,150',
#   '$250',
#   '$50',
#   '$1,500',
#   '$350',
#   '$20',
#   '$50',
#   '$75',
#   '$3,000',
#   '$570',
#   '$150',
#   '$1,500',
#   '$2',
#   '$100',
#   '$30',
#   '$275',
#   '$600',
#   '$400',
#   '$195',
#   '$90',
#   '$4,200',
#   '$2,400',
#   '$300',
#   '$100',
#   '$40',
#   '$1,300',
#   '$800',
#   '$450',
#   '$100',
#   '$1,500',
#   '$55',
#   '$80',
#   '$1,400',
#   '$800',
#   '$500',
#   '$250',
#   '$99',
#   '$1,200',
#   '$200',
#   '$20',
#   '$1,200',
#   '$1,000',
#   '$475',
#   '$45',
#   '$160',
#   '$145',
#   '$750',
#   '$275',
#   '$300',
#   '$600',
#   '$6,900',
#   '$300',
#   '$80',
#   '$0',
#   '$200',
#   '$100',
#   '$550',
#   '$0',
#   '$65',
#   '$80',
#   '$100',
#   '$300',
#   '$10',
#   '$2,600',
#   '$1,800',
#   '$800',
#   '$125',
#   '$2,500',
#   '$2,000',
#   '$175',
#   '$100',
#   '$800',
#   '$50',
#   '$20',
#   '$275',
#   '$0',
#   '$350',
#   '$225',
#   '$110',
#   '$2,400',
#   '$2,500',
#   '$115',
#   '$4,500',
#   '$850',
#   '$500',
#   '$65',
#   '$250',
#   '$500',
#   '$125',
#   '$65',
#   '$0',
#   '$600',
#   '$100',
#   '$100',
#   '$185',
#   '$65',
#   '$290',
#   '$290',
#   '$80',
#   '$150',
#   '$10',
#   '$300',
#   '$225',
#   '$125',
#   '$250',
#   '$250',
#   '$150',
#   '$40',
#   '$0',
#   '$750',
#   '$60',
#   '$200',
#   '$145',
#   '$10',
#   '$50',
#   '$10',
#   '$1,000',
#   '$350',
#   '$268',
#   '$152',
#   '$350',
#   '$725',
#   '$800',
#   '$55',
#   '$1,650',
#   '$10',
#   '$770',
#   '$1,650',
#   '$200',
#   '$999',
#   '$300',
#   '$75',
#   '$400',
#   '$200',
#   '$85',
#   '$85',
#   '$25',
#   '$20',
#   '$1',
#   '$0',
#   '$40',
#   '$550',
#   '$60',
#   '$0',
#   '$0',
#   '$300',
#   '$90',
#   '$275',
#   '$80',
#   '$45',
#   '$30',
#   '$3,500',
#   '$35',
#   '$45',
#   '$75',
#   '$220',
#   '$450',
#   '$0',
#   '$0',
#   '$0',
#   '$6,250',
#   '$350',
#   '$450',
#   '$60',
#   '$125',
#   '$400',
#   '$50',
#   '$0',
#   '$0',
#   '$75',
#   '$135',
#   '$85',
#   '$45',
#   '$400',
#   '$550',
#   '$2,700',
#   '$750',
#   '$750',
#   '$650',
#   '$1,250',
#   '$0',
#   '$300',
#   '$1,900',
#   '$1,250',
#   '$0',
#   '$300',
#   '$1,900',
#   '$75',
#   '$350',
#   '$420',
#   '$0',
#   '$599',
#   '$375',
#   '$900',
#   '$950',
#   '$65',
#   '$65',
#   '$925',
#   '$80',
#   '$350',
#   '$25',
#   '$50',
#   '$50',
#   '$75',
#   '$325',
#   '$75',
#   '$800',
#   '$600',
#   '$1,000',
#   '$500',
#   '$300',
#   '$800',
#   '$1,600',
#   '$3,500',
#   '$4,800',
#   '$950',
#   '$1,000',
#   '$2,000',
#   '$1,000',
#   '$1,300',
#   '$200',
#   '$500',
#   '$800',
#   '$400',
#   '$0',
#   '$0',
#   '$25',
#   '$695',
#   '$2,495',
#   '$445',
#   '$40',
#   '$5',
#   '$145',
#   '$75',
#   '$10',
#   '$10',
#   '$5',
#   '$5',
#   '$300',
#   '$200',
#   '$200',
#   '$25',
#   '$20',
#   '$150',
#   '$225',
#   '$3,400',
#   '$50',
#   '$300',
#   '$100',
#   '$75',
#   '$400',
#   '$75',
#   '$180',
#   '$250',
#   '$50',
#   '$60',
#   '$25',
#   '$40',
#   '$165',
#   '$550',
#   '$275',
#   '$250',
#   '$2,295',
#   '$150',
#   '$130',
#   '$500',
#   '$1,600',
#   '$2,000',
#   '$10',
#   '$280',
#   '$0',
#   '$15',
#   '$35',
#   '$75',
#   '$192',
#   '$1',
#   '$140',
#   '$300',
#   '$300',
#   '$120',
#   '$300',
#   '$80',
#   '$260',
#   '$195',
#   '$150',
#   '$350',
#   '$25',
#   '$1,400',
#   '$199',
#   '$700',
#   '$1,950',
#   '$20',
#   '$0',
#   '$275',
#   '$40',
#   '$300',
#   '$199',
#   '$199',
#   '$99',
#   '$80',
#   '$275',
#   '$99',
#   '$199',
#   '$30',
#   '$130',
#   '$99',
#   '$249',
#   '$99',
#   '$99',
#   '$120',
#   '$99',
#   '$99',
#   '$25',
#   '$190',
#   '$65',
#   '$700',
#   '$65',
#   '$75',
#   '$950',
#   '$850',
#   '$200',
#   '$50',
#   '$3,000',
#   '$600',
#   '$110',
#   '$75',
#   '$220',
#   '$1,450',
#   '$200',
#   '$1,200',
#   '$30',
#   '$0',
#   '$45',
#   '$4,550',
#   '$850',
#   '$100',
#   '$450',
#   '$100',
#   '$250',
#   '$150',
#   '$1',
#   '$300',
#   '$69',
#   ...],
#  'pics': ['True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'False',
#   'False',
#   'True',
#   'False',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'False',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'False',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'False',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'False',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   'True',
#   ...],
#  'hood': [' (sebastopol)',
#   ' (sebastopol)',
#   ' (sebastopol)',
#   ' (los gatos)',
#   ' (los gatos)',
#   ' (los gatos)',
#   ' (danville / san ramon)',
#   'NONE',
#   ' (milpitas)',
#   ' (alameda)',
#   ' (mill valley)',
#   ' (concord / pleasant hill / martinez)',
#   ' (los gatos)',
#   ' (mill valley)',
#   ' (mill valley)',
#   ' (castro / upper market)',
#   ' (mill valley)',
#   ' (mill valley)',
#   ' (lafayette / orinda / moraga)',
#   ' (oakland hills / mills)',
#   ' (lafayette / orinda / moraga)',
#   ' (glen park)',
#   ' (emeryville)',
#   ' (Aptos)',
#   ' (dublin / pleasanton / livermore)',
#   ' (hayward / castro valley)',
#   'NONE',
#   ' (hayward / castro valley)',
#   ' (dublin / pleasanton / livermore)',
#   ' (hayward / castro valley)',
#   ' (san jose east)',
#   ' (Berkeley)',
#   ' (milpitas)',
#   ' (napa county)',
#   ' (lafayette / orinda / moraga)',
#   ' (downtown / civic / van ness)',
#   ' (menlo park)',
#   ' (dublin / pleasanton / livermore)',
#   ' (sonoma)',
#   ' (oakland lake merritt / grand)',
#   ' (San Francisco)',
#   ' (San Francisco)',
#   ' (Point Richmond)',
#   ' (south san francisco)',
#   ' (alameda)',
#   ' (Mountain View)',
#   ' (Sunnyvale)',
#   ' (san leandro)',
#   ' (sunnyvale)',
#   ' (mountain view)',
#   ' (mountain view)',
#   ' (Mountain View)',
#   ' (Mountain View)',
#   ' (san jose south)',
#   ' (Mountain View)',
#   ' (rohnert pk / cotati)',
#   ' (richmond / point / annex)',
#   ' (richmond / point / annex)',
#   ' (Mountain View)',
#   ' (san jose south)',
#   ' (Mountain View)',
#   ' (san jose south)',
#   ' (Petaluma)',
#   ' (milpitas)',
#   ' (santa cruz)',
#   ' (oakland hills / mills)',
#   ' (oakland hills / mills)',
#   ' (oakland hills / mills)',
#   ' (oakland hills / mills)',
#   ' (south san francisco)',
#   ' (San Francisco)',
#   ' (portola district)',
#   ' (sunnyvale)',
#   ' (san jose downtown)',
#   ' (sonoma)',
#   ' (santa cruz)',
#   ' (excelsior / outer mission)',
#   ' (mountain view)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (santa clara)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (aptos)',
#   ' (aptos)',
#   ' (aptos)',
#   ' (aptos)',
#   ' (aptos)',
#   ' (belmont)',
#   ' (north beach / telegraph hill)',
#   ' (mountain view)',
#   ' (berkeley)',
#   ' (sunnyvale)',
#   ' (sunnyvale)',
#   ' (oakland lake merritt / grand)',
#   ' (oakland lake merritt / grand)',
#   ' (santa cruz)',
#   ' (lafayette / orinda / moraga)',
#   ' (aptos)',
#   ' (portola district)',
#   ' (oakland piedmont / montclair)',
#   ' (marina / cow hollow)',
#   ' (oakland piedmont / montclair)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (pacifica)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (Emeryville)',
#   ' (saratoga)',
#   ' (hayward / castro valley)',
#   ' (saratoga)',
#   ' (saratoga)',
#   ' (saratoga)',
#   'NONE',
#   ' (san jose north)',
#   ' (north beach / telegraph hill)',
#   ' (los gatos)',
#   ' (santa rosa)',
#   ' (santa cruz)',
#   ' (san jose east)',
#   ' (santa cruz)',
#   ' (Menlo Park)',
#   ' (oakland rockridge / claremont)',
#   ' (oakland lake merritt / grand)',
#   ' (western addition)',
#   ' (lafayette / orinda / moraga)',
#   ' (north beach / telegraph hill)',
#   ' (danville / san ramon)',
#   ' (oakland lake merritt / grand)',
#   ' (lafayette / orinda / moraga)',
#   'NONE',
#   ' (alameda)',
#   ' (San Francisco)',
#   ' (north beach / telegraph hill)',
#   ' (oakland downtown)',
#   'NONE',
#   ' (danville / san ramon)',
#   ' (santa cruz)',
#   ' (north beach / telegraph hill)',
#   ' (santa rosa)',
#   ' (SALINAS)',
#   ' (oakland north / temescal)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (oakland downtown)',
#   ' (mountain view)',
#   ' (potrero hill)',
#   ' (hayward / castro valley)',
#   ' (SOMA / south beach)',
#   ' (SOMA / south beach)',
#   ' (hayward / castro valley)',
#   ' (redwood city)',
#   ' (Oroville)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (concord / pleasant hill / martinez)',
#   ' (oakland lake merritt / grand)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (oakland rockridge / claremont)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (salinas)',
#   'NONE',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (redwood city)',
#   ' (san jose west)',
#   ' (Redwood City)',
#   ' (san jose north)',
#   ' (redwood city)',
#   ' (santa cruz)',
#   ' (excelsior / outer mission)',
#   ' (san leandro)',
#   ' (salinas)',
#   ' (brentwood / oakley)',
#   ' (lafayette / orinda / moraga)',
#   ' (san jose north)',
#   ' (SAN JOSE)',
#   ' (salinas)',
#   ' (castro / upper market)',
#   ' (north beach / telegraph hill)',
#   ' (castro / upper market)',
#   ' (castro / upper market)',
#   ' (castro / upper market)',
#   ' (castro / upper market)',
#   ' (lafayette / orinda / moraga)',
#   ' (petaluma)',
#   ' (west portal / forest hill)',
#   ' (dublin / pleasanton / livermore)',
#   ' (campbell)',
#   ' (lafayette / orinda / moraga)',
#   ' (salinas)',
#   'NONE',
#   ' (santa cruz)',
#   ' (western addition)',
#   ' (dublin / pleasanton / livermore)',
#   ' (south san francisco)',
#   ' (salinas)',
#   'NONE',
#   ' (san jose north)',
#   ' (san rafael)',
#   ' (lafayette / orinda / moraga)',
#   ' (san rafael)',
#   ' (san leandro)',
#   ' (petaluma)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (santa cruz)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (salinas)',
#   ' (western addition)',
#   ' (willow glen / cambrian)',
#   ' (santa rosa)',
#   ' (santa rosa)',
#   ' (fairfax)',
#   ' (mountain view)',
#   ' (lafayette / orinda / moraga)',
#   ' (concord / pleasant hill / martinez)',
#   ' (fairfax)',
#   ' (mountain view)',
#   ' (lafayette / orinda / moraga)',
#   ' (concord / pleasant hill / martinez)',
#   ' (santa clara)',
#   ' (Richmond)',
#   ' (mountain view)',
#   ' (salinas)',
#   ' (alameda)',
#   ' (alameda)',
#   ' (san jose south)',
#   ' (berkeley)',
#   ' (lafayette / orinda / moraga)',
#   ' (salinas)',
#   ' (San Francisco)',
#   ' (potrero hill)',
#   ' (oakland piedmont / montclair)',
#   ' (sunset / parkside)',
#   ' (santa clara)',
#   ' (sunset / parkside)',
#   ' (sunset / parkside)',
#   ' (santa cruz)',
#   ' (petaluma)',
#   'NONE',
#   'NONE',
#   'NONE',
#   ' (San Jose)',
#   'NONE',
#   ' (morgan hill)',
#   ' (daly city)',
#   ' (fremont / union city / newark)',
#   ' (palo alto)',
#   ' (sebastopol)',
#   ' (San Francisco)',
#   ' (lafayette / orinda / moraga)',
#   ' (alameda)',
#   ' (san jose south)',
#   ' (San jose)',
#   ' (hayward / castro valley)',
#   ' (inner richmond)',
#   ' (inner richmond)',
#   ' (bayview)',
#   ' (half moon bay)',
#   ' (Sebastopol)',
#   ' (alameda)',
#   ' (san jose south)',
#   ' (berkeley north / hills)',
#   ' (berkeley)',
#   ' (santa cruz)',
#   ' (berkeley)',
#   ' (san jose east)',
#   ' (gilroy)',
#   ' (burlingame)',
#   ' (petaluma)',
#   ' (santa cruz)',
#   ' (vallejo / benicia)',
#   ' (santa rosa)',
#   ' (gilroy)',
#   ' (petaluma)',
#   ' (oakland lake merritt / grand)',
#   ' (san rafael)',
#   ' (oakland lake merritt / grand)',
#   ' (san jose south)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (mill valley)',
#   ' (fremont / union city / newark)',
#   ' (mill valley)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (fremont / union city / newark)',
#   ' (greenbrae)',
#   ' (fremont / union city / newark)',
#   ' (alameda)',
#   ' (los gatos)',
#   ' (san leandro)',
#   ' (san leandro)',
#   'NONE',
#   ' (san leandro)',
#   ' (san leandro)',
#   ' (willow glen / cambrian)',
#   ' (dublin / pleasanton / livermore)',
#   ' (san leandro)',
#   ' (fremont / union city / newark)',
#   ' (san mateo)',
#   ' (concord / pleasant hill / martinez)',
#   ' (santa cruz)',
#   ' (alameda)',
#   ' (kentfield / ross)',
#   ' (scotts valley)',
#   ' (USF / panhandle)',
#   ' (USF / panhandle)',
#   ' (USF / panhandle)',
#   ' (fremont / union city / newark)',
#   ' (santa rosa)',
#   ' (Felton)',
#   ' (sunnyvale)',
#   ' (bernal heights)',
#   ' (Rohnert Park)',
#   ' (sunset / parkside)',
#   ' (Rohnert Park)',
#   ' (concord / pleasant hill / martinez)',
#   ' (San Francisco)',
#   ' (willow glen / cambrian)',
#   ' (san jose west)',
#   ' (Potrero Hill)',
#   ' (san jose west)',
#   ' (hayward / castro valley)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (san jose east)',
#   ' (dublin / pleasanton / livermore)',
#   ' (palo alto)',
#   ' (mountain view)',
#   ' (albany / el cerrito)',
#   ' (novato)',
#   ' (emeryville)',
#   ' (San Francisco)',
#   ' (san leandro)',
#   ' (Oakland)',
#   ' (Oakland)',
#   ' (scotts valley)',
#   ' (Oakland)',
#   ' (Oakland)',
#   ' (burlingame)',
#   ' (albany / el cerrito)',
#   ' (Richmond)',
#   ' (novato)',
#   ' (oakland piedmont / montclair)',
#   ' (lafayette / orinda / moraga)',
#   ' (santa rosa)',
#   ' (santa rosa)',
#   ' (concord / pleasant hill / martinez)',
#   ' (dublin / pleasanton / livermore)',
#   ' (oakland north / temescal)',
#   ' (Pleasanton)',
#   ' (Anywhere)',
#   ' (inner sunset / UCSF)',
#   ' (san jose south)',
#   ' (san jose south)',
#   ' (oakland lake merritt / grand)',
#   ' (Penngrove)',
#   ' (marina / cow hollow)',
#   ' (san jose south)',
#   ' (downtown / civic / van ness)',
#   ' (inner sunset / UCSF)',
#   ' (san jose south)',
#   ' (castro / upper market)',
#   ' (haight ashbury)',
#   ' (bernal heights)',
#   ' (noe valley)',
#   ' (San Jose)',
#   ' (mission district)',
#   ' (sausalito)',
#   ' (hayes valley)',
#   ' (sausalito)',
#   ' (Felton)',
#   ' (gilroy)',
#   ' (bernal heights)',
#   ' (vallejo / benicia)',
#   ' (sonoma)',
#   ' (oakland hills / mills)',
#   ' (oakland hills / mills)',
#   ' (albany / el cerrito)',
#   ' (SOMA / south beach)',
#   ' (albany / el cerrito)',
#   ' (financial district)',
#   ' (SOMA / south beach)',
#   ' (vallejo / benicia)',
#   ' (Felton)',
#   ' (redwood city)',
#   ' (vallejo / benicia)',
#   ' (Glen Park)',
#   ' (vallejo / benicia)',
#   ' (santa clara)',
#   ' (sunnyvale)',
#   ' (vallejo / benicia)',
#   ' (berkeley north / hills)',
#   ' (sonoma)',
#   ' (willow glen / cambrian)',
#   ' (berkeley north / hills)',
#   ' (SOMA / south beach)',
#   ' (santa rosa)',
#   ' (San Mateo)',
#   ' (berkeley north / hills)',
#   ' (palo alto)',
#   ' (San Pablo)',
#   ' (hollister)',
#   ' (San Pablo)',
#   ' (San Pablo)',
#   ' (san rafael)',
#   ' (sunnyvale)',
#   ' (San Pablo)',
#   ' (San Pablo)',
#   ' (oakland north / temescal)',
#   ' (San Pablo)',
#   ' (oakland east)',
#   ' (oakland rockridge / claremont)',
#   ' (oakland rockridge / claremont)',
#   ' (sonoma)',
#   ' (millbrae)',
#   ' (millbrae)',
#   ' (millbrae)',
#   ' (san carlos)',
#   'NONE',
#   ' (san jose north)',
#   ' (albany / el cerrito)',
#   ' (berkeley)',
#   ' (albany / el cerrito)',
#   ' (sunnyvale)',
#   ' (daly city)',
#   ' (fremont / union city / newark)',
#   ' (vallejo / benicia)',
#   ' (daly city)',
#   ' (santa rosa)',
#   ' (hayward / castro valley)',
#   ' (berkeley)',
#   ' (daly city)',
#   ' (daly city)',
#   ' (san jose west)',
#   ' (daly city)',
#   ' (san jose west)',
#   ' (daly city)',
#   ' (berkeley)',
#   ' (daly city)',
#   ' (santa cruz)',
#   ' (inner richmond)',
#   ' (San Mateo)',
#   ' (daly city)',
#   ' (Aromas)',
#   ' (watsonville)',
#   ' (San Jose)',
#   ' (daly city)',
#   ' (daly city)',
#   ' (daly city)',
#   ' (burlingame)',
#   ' (haight ashbury)',
#   ' (walnut creek)',
#   ' (oakland west)',
#   ' (walnut creek)',
#   ' (berkeley)',
#   'NONE',
#   ' (Walnut Creek)',
#   ' (daly city)',
#   ' (berkeley)',
#   ' (burlingame)',
#   ' (Hayward)',
#   ' (berkeley)',
#   ' (oakland piedmont / montclair)',
#   ' (Walnut Creek)',
#   ' (berkeley)',
#   ' (financial district)',
#   ' (berkeley)',
#   ' (santa rosa)',
#   'NONE',
#   ' (san leandro)',
#   ' (alameda)',
#   ' (pittsburg / antioch)',
#   ' (petaluma)',
#   ' (san jose north)',
#   ' (berkeley)',
#   ' (san jose north)',
#   ' (berkeley)',
#   ' (san mateo)',
#   ' (san jose north)',
#   ' (berkeley)',
#   ' (san mateo)',
#   ' (palo alto)',
#   ' (mountain view)',
#   ' (half moon bay)',
#   ' (San Jose)',
#   ' (larkspur)',
#   ' (Walnut Creek)',
#   ' (berkeley)',
#   ' (hayward / castro valley)',
#   ' (aptos)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (san jose east)',
#   ' (healdsburg / windsor)',
#   ' (san bruno)',
#   ' (san leandro)',
#   ' (brentwood / oakley)',
#   'NONE',
#   ' (richmond / point / annex)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (berkeley)',
#   ' (santa cruz)',
#   ' (berkeley)',
#   ' (Santa Clara)',
#   ' (Walnut Creek)',
#   ' (berkeley)',
#   ' (santa cruz)',
#   ' (berkeley)',
#   ' (concord / pleasant hill / martinez)',
#   ' (berkeley)',
#   ' (dublin / pleasanton / livermore)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (inner sunset / UCSF)',
#   ' (concord / pleasant hill / martinez)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (milpitas)',
#   ' (berkeley)',
#   ' (san jose west)',
#   ' (berkeley)',
#   ' (north beach / telegraph hill)',
#   ' (north beach / telegraph hill)',
#   ' (north beach / telegraph hill)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (oakland hills / mills)',
#   ' (san anselmo)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (mountain view)',
#   ' (Oakland)',
#   ' (hayward / castro valley)',
#   ' (vallejo / benicia)',
#   ' (Danville)',
#   ' (san jose east)',
#   ' (richmond / point / annex)',
#   ' (richmond / point / annex)',
#   ' (lafayette / orinda / moraga)',
#   ' (lafayette / orinda / moraga)',
#   ' (Santa Rosa)',
#   ' (sausalito)',
#   ' (sebastopol)',
#   ' (petaluma)',
#   ' (sunnyvale)',
#   ' (oakland piedmont / montclair)',
#   ' (San Francisco)',
#   ' (San Francisco)',
#   ' (San Francisco)',
#   ' (kentfield / ross)',
#   ' (petaluma)',
#   ' (Roseville)',
#   ' (gilroy)',
#   ' (dublin / pleasanton / livermore)',
#   ' (Mountain View)',
#   ' (Atherton)',
#   ' (Atherton)',
#   ' (Atherton)',
#   ' (Kenwood)',
#   ' (mission district)',
#   ' (Mission)',
#   ' (Kenwood)',
#   ' (west marin)',
#   ' (west marin)',
#   ' (berkeley)',
#   ' (brentwood / oakley)',
#   ' (santa cruz)',
#   ' (san francisco)',
#   ' (brentwood / oakley)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (rohnert pk / cotati)',
#   ' (san francisco)',
#   ' (El Sobrante)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (nob hill)',
#   ' (nob hill)',
#   ' (san francisco)',
#   ' (San Francisco)',
#   ' (alameda)',
#   ' (danville / san ramon)',
#   ' (sonoma)',
#   ' (inner sunset / UCSF)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (saratoga)',
#   ' (San Jose)',
#   ' (sebastopol)',
#   ' (pittsburg / antioch)',
#   ' (oakland north / temescal)',
#   ' (San Francisco)',
#   ' (San Francisco)',
#   ' (Ashland)',
#   ' (nob hill)',
#   ' (san jose downtown)',
#   'NONE',
#   ' (sebastopol)',
#   ' (berkeley)',
#   ' (emeryville)',
#   ' (oakland lake merritt / grand)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (cupertino)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (san jose west)',
#   ' (nob hill)',
#   ' (san jose west)',
#   ' (petaluma)',
#   ' (san jose south)',
#   ' (santa clara)',
#   ' (San Mateo)',
#   ' (oakland lake merritt / grand)',
#   ' (Novato)',
#   ' (novato)',
#   ' (novato)',
#   ' (alameda)',
#   ' (inner richmond)',
#   ' (Willow Glen)',
#   ' (San Mateo)',
#   ' (foster city)',
#   ' (redwood city)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (san jose south)',
#   ' (san jose west)',
#   ' (El Sobrante)',
#   ' (san jose west)',
#   ' (San Francisco)',
#   ' (san mateo)',
#   ' (rohnert pk / cotati)',
#   ' (santa rosa)',
#   ' (santa cruz)',
#   ' (Daly City)',
#   ' (daly city)',
#   ' (san mateo)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (mill valley)',
#   ' (daly city)',
#   ' (mountain view)',
#   ' (san rafael)',
#   ' (sunnyvale)',
#   ' (san mateo)',
#   ' (San Mateo)',
#   ' (santa cruz)',
#   ' (willow glen / cambrian)',
#   ' (san jose downtown)',
#   ' (Campbell)',
#   ' (santa cruz)',
#   ' (san jose west)',
#   ' (san rafael)',
#   ' (santa cruz)',
#   ' (woodside)',
#   ' (santa cruz)',
#   ' (san jose downtown)',
#   ' (brentwood / oakley)',
#   ' (soquel)',
#   ' (danville / san ramon)',
#   ' (fremont / union city / newark)',
#   ' (walnut creek)',
#   ' (sebastopol)',
#   ' (north beach / telegraph hill)',
#   ' (lafayette / orinda / moraga)',
#   ' (Montara, Ca)',
#   ' (redwood city)',
#   ' (san jose south)',
#   ' (san jose south)',
#   ' (pacifica)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (ingleside / SFSU / CCSF)',
#   ' (sebastopol)',
#   ' (hayward / castro valley)',
#   ' (rohnert pk / cotati)',
#   ' (santa rosa)',
#   ' (rohnert pk / cotati)',
#   ' (rohnert pk / cotati)',
#   ' (Tracy)',
#   ' (rohnert pk / cotati)',
#   ' (santa rosa)',
#   ' (Fremont)',
#   ' (west portal / forest hill)',
#   ' (foster city)',
#   ' (dublin / pleasanton / livermore)',
#   ' (willow glen / cambrian)',
#   ' (brentwood / oakley)',
#   ' (bernal heights)',
#   'NONE',
#   ' (walnut creek)',
#   ' (lake county)',
#   ' (novato)',
#   ' (fremont / union city / newark)',
#   ' (concord / pleasant hill / martinez)',
#   'NONE',
#   ' (oakland lake merritt / grand)',
#   ' (milpitas)',
#   ' (Fremont)',
#   ' (milpitas)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   'NONE',
#   ' (bernal heights)',
#   ' (bernal heights)',
#   ' (brentwood / oakley)',
#   ' (santa cruz)',
#   ' (bernal heights)',
#   ' (bernal heights)',
#   'NONE',
#   ' (danville / san ramon)',
#   ' (Tracy)',
#   ' (San Jose)',
#   ' (redwood city)',
#   ' (Santa Cruz)',
#   ' (berkeley north / hills)',
#   ' (berkeley north / hills)',
#   ' (san jose east)',
#   ' (berkeley north / hills)',
#   ' (San Francisco)',
#   ' (Santa Cruz)',
#   ' (Fremont)',
#   ' (Fremont CA)',
#   ' (excelsior / outer mission)',
#   ' (concord / pleasant hill / martinez)',
#   ' (Mission)',
#   ' (san jose downtown)',
#   ' (redwood city)',
#   ' (fremont / union city / newark)',
#   ' (downtown / civic / van ness)',
#   ' (redwood city)',
#   ' (vallejo / benicia)',
#   ' (ARROYO GRANDE)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (Mission)',
#   ' (mission district)',
#   ' (mission district)',
#   ' (mission district)',
#   ' (Redwood City)',
#   ' (Redwood City)',
#   ' (sunnyvale)',
#   ' (Tracy)',
#   ' (sebastopol)',
#   ' (San Juan Bautista)',
#   ' (San Juan Bautista)',
#   ' (San Juan Bautista)',
#   ' (San Juan Bautista)',
#   ' (santa rosa)',
#   ' (rohnert pk / cotati)',
#   ' (sebastopol)',
#   ' (rohnert pk / cotati)',
#   ' (rohnert pk / cotati)',
#   ' (rohnert pk / cotati)',
#   ' (Aptos)',
#   ' (san jose south)',
#   ' (san anselmo)',
#   ' (inner richmond)',
#   ' (santa clara)',
#   ' (noe valley)',
#   'NONE',
#   ' (Tracy)',
#   ' (castro / upper market)',
#   ' (castro / upper market)',
#   ' (hayward / castro valley)',
#   ' (hercules, pinole, san pablo, el sob)',
#   ' (santa rosa)',
#   ' (santa rosa)',
#   ' (vallejo / benicia)',
#   ' (santa rosa)',
#   ' (Tracy)',
#   ' (Tracy)',
#   ' (berkeley north / hills)',
#   ' (berkeley north / hills)',
#   ' (berkeley north / hills)',
#   ' (palo alto)',
#   ' (berkeley)',
#   ' (Sonoma)',
#   ' (North Bay)',
#   ' (Sonoma)',
#   ' (Tracy)',
#   ' (Tracy)',
#   ' (Tracy)',
#   'NONE',
#   ' (san jose south)',
#   ' (santa rosa)',
#   ' (Tracy)',
#   'NONE',
#   ' (san jose south)',
#   ' (santa rosa)',
#   ' (Fremont)',
#   ' (concord / pleasant hill / martinez)',
#   ' (san rafael)',
#   'NONE',
#   ' (Tracy)',
#   ' (concord / pleasant hill / martinez)',
#   ' (santa rosa)',
#   ' (sunnyvale)',
#   ' (novato)',
#   ' (novato)',
#   ' (pittsburg / antioch)',
#   ' (novato)',
#   ' (pittsburg / antioch)',
#   ' (pittsburg / antioch)',
#   ' (pittsburg / antioch)',
#   ' (pittsburg / antioch)',
#   ' (pittsburg / antioch)',
#   ' (pittsburg / antioch)',
#   ' (berkeley)',
#   ' (berkeley)',
#   ' (oakland hills / mills)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (hollister)',
#   ' (mountain view)',
#   ' (lafayette / orinda / moraga)',
#   ' (lafayette / orinda / moraga)',
#   ' (lafayette / orinda / moraga)',
#   'NONE',
#   ' (Tracy)',
#   ' (san jose south)',
#   ' (Berkeley)',
#   ' (sunnyvale)',
#   ' (saratoga)',
#   ' (dublin / pleasanton / livermore)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (lafayette / orinda / moraga)',
#   ' (santa cruz)',
#   ' (USF / panhandle)',
#   ' (santa cruz)',
#   ' (USF / panhandle)',
#   ' (Sonora)',
#   ' (Sonora)',
#   ' (Sonora)',
#   ' (san leandro)',
#   ' (san leandro)',
#   ' (san leandro)',
#   ' (scotts valley)',
#   ' (fremont / union city / newark)',
#   ' (scotts valley)',
#   ' (concord / pleasant hill / martinez)',
#   ' (concord / pleasant hill / martinez)',
#   ' (scotts valley)',
#   ' (danville / san ramon)',
#   ' (scotts valley)',
#   ' (petaluma)',
#   ' (petaluma)',
#   ' (petaluma)',
#   ' (petaluma)',
#   ' (san jose south)',
#   ' (Fremont)',
#   ' (pacifica)',
#   ' (daly city)',
#   ' (pacifica)',
#   ' (pacifica)',
#   ' (fremont / union city / newark)',
#   ' (downtown / civic / van ness)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (hayward / castro valley)',
#   ' (fremont / union city / newark)',
#   ' (willow glen / cambrian)',
#   ' (haight ashbury)',
#   ' (hayward / castro valley)',
#   ' (pittsburg / antioch)',
#   ' (dublin / pleasanton / livermore)',
#   ' (concord / pleasant hill / martinez)',
#   ' (albany / el cerrito)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (san francisco)',
#   ' (daly city)',
#   ' (daly city)',
#   ' (daly city)',
#   ' (brisbane)',
#   ' (san jose south)',
#   ' (san jose downtown)',
#   ' (walnut creek)',
#   ' (brisbane)',
#   ' (pacifica)',
#   ' (napa county)',
#   ' (mission district)',
#   ' (mission district)',
#   ' (mission district)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (bayview)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (vallejo / benicia)',
#   ' (south san francisco)',
#   ' (mission district)',
#   ' (los gatos)',
#   ' (walnut creek)',
#   ' (los gatos)',
#   ' (alameda)',
#   ' (alameda)',
#   ' (cupertino)',
#   ' (sebastopol)',
#   ' (petaluma)',
#   ' (san carlos)',
#   ' (los gatos)',
#   ' (los gatos)',
#   ' (los gatos)',
#   ' (Fairfield)',
#   ' (Fairfield)',
#   ' (alameda)',
#   ' (Fairfield)',
#   ' (oakland lake merritt / grand)',
#   ' (belmont)',
#   ' (San Mateo)',
#   ' (santa cruz)',
#   ' (santa cruz)',
#   ' (petaluma)',
#   ' (Petaluma)',
#   ' (El Cerrito)',
#   ' (sunnyvale)',
#   ' (santa cruz)',
#   ' (castro / upper market)',
#   ' (milpitas)',
#   ' (castro / upper market)',
#   ...],
#  'title': ['Ibanez MC200 Musician Series Guitar',
#   'Fender Performer 1000 amp',
#   'Fender Champ 12',
#   'Ovation Guitar',
#   '!!! 2017 YULONG GUO ZIRICOTE CONCERT GUITAR - DOUBLE TOP !!!',
#   'Schecter Hellraiser',
#   'CONN Director "Shooting Stars" Trumpet',
#   'Marshall 1987X  50watt Amp',
#   'Student Tenor Trombone Besson 2-20 made in England',
#   'F-Bass BN5 Ceruse Black - Mint',
#   'Yamaha F325 Acoustic Guitar with gig bag and strap',
#   'Fender Sidekick Reverb 35',
#   'Wurlitzer Upright Piano, antique',
#   'Vintage Gibson Lap Steel Guitar Case. Could be Fender or Rickenbacker',
#   'Rick Derringer Signed Guitar.  Authentic.  Open to Trades',
#   'Vintage Marshall Acoustic Soloist Combo Guitar AS80R  Amp',
#   'Pyle PYX-3X 3 way electronic crossover x-over (open to trades)',
#   '1978 Marshall Stack in Rare Fawn 50 watt JMP 2204 (All Types Trades OK',
#   'Road Runner RRDNMC DJ equipment',
#   'Roland SPD-X w/ accessories',
#   'Shure SM58 wireless BLX24 w/box',
#   'Roland Orange Cube 100',
#   'Native Instruments Maschine MK1 Controller',
#   '2017 Martin 000-15M acoustic guitar',
#   'Nearly New Yamaha 82Zii Tenor Sax',
#   '24-fret unfinished neck',
#   'Behringer 2x12 modeling guitar/keyboard/.DJ/PA/Karaoke amp',
#   'Warmoth 12-string+ HSC',
#   'Leslie Speaker Bass Rotors',
#   'Nice SX Jazz archtop + Hard Case(clip available)',
#   'UDG DJ record bag',
#   'Roland K25m Keyboard for Boutiques Trade/Sell',
#   'Gator padded soft Bass case',
#   "VINTAGE 1940'S SS STEWART ARTDECO MANDOLIN/DEARMAND PICKUP! TRADES?",
#   'Quantegy GP9 2” Tape',
#   'Ampeg Bass Speaker Cabinet 15in 15 OBO',
#   'FS: Akai MPK Mini Play',
#   'Roland td15kv',
#   'Wurlitzer piano',
#   'South American 6 string tiny guitar or "ukelele"',
#   'BRAND NEW Orange Micro Dark amp head',
#   'Valencia 1/2  size nylon string guitar',
#   '6 piece Sonor 2003 Powerforce drum kit',
#   'Roland FP-90 digital piano, RPU-3 pedal unit, stand',
#   'Peavey Delta Blues 1-15" tube combo amp',
#   'Kawai Mav-8 Midi Patchbay',
#   'Samson Concert TD Series CR-2 Receiver',
#   'Yamaha PSR-170 Piano Keyboard',
#   'Hercules Tuba/Euphonium Stand',
#   'Yamaha Volume /Expression Pedal',
#   'MOTU Midi Time Piece II',
#   'DigiTech DSP 256 Multi Effects Processor',
#   'Midiman Oxygen 8 Keyboard',
#   'United Audio Apollo 8 QUAD',
#   'Alesis Keyboard or Drum Machine Foot-Switch  Pedal 93',
#   'Conn Sax',
#   'GSB EWJB-20CE Acoustic Bass Natural',
#   "Fernandes FRB-90 Fretless 4 String Early 2000's Seethrough Purple",
#   'Alesis Microgate, Noise Gate',
#   'Crate Guitar Amplifier GX15R',
#   'Alesis Micro Enhancer',
#   'Fender Rumble 150 Bass Amplifier',
#   'Peavey XXX 120 watt 2x12 combo',
#   'Williams Legato 88-Key Digital Piano',
#   'Gretsch Round Badge Drum Set 12/14/20',
#   '1950’s Magnavox P-232, 15” Guitar Speaker',
#   'Eminence Delta 15A Speaker',
#   'Fender 12" Guitar Speaker',
#   'Guitar Warehouse 15" Speaker and cabinet',
#   '1965 Vintage Fender Super Rever Blackface guitar amp amplifier',
#   'Carvin BX 500 Combo Bass Amplifier',
#   'Jupiter Trombone',
#   'Roland UA-1010 OCTA-CAPTURE 10-input, 10-output Hi-speed USB Audio Int',
#   'Avid Eleven Rack Guitar Multi-Effects Processor',
#   'Epiphone Wildkat W/ Lollar upgrades',
#   '1922 Juzek Violin - Nice!',
#   'Tama Swingstar 4 piece drum set',
#   'Baldwin player piano',
#   'Ensoniq TS-10 Perfomance/Composition Synthesizer',
#   'Mapex Qualifier 16x14 Bass Drum',
#   'Radian 1” hf driver',
#   'Esp Brett garsed signature horizon',
#   'Jbl 2404H-1 baby cheeks tweeter',
#   'Fuchs tripledrive supreme HRM 150',
#   'Amperex bugle boy mullard   5ar4 gz34',
#   'Crossovers 3 way',
#   'Fractal Axefx ultra. (Mint)',
#   'Fender american standard stratocaster mint condition in rare color',
#   'VINTAGE DW DRUMS',
#   'REMO 24" BASS DRUM HEADS.NEW.',
#   'VINTAGE LUDWIG RED SPARKLE TOMS',
#   '16" PAISTE ALPHA POWER CRASH',
#   'DRUM CLEARANCE',
#   'Anvil (Vintage) Flightcase *Briefcase/Suitcase',
#   'Royer R-122 Ribbon Microphone Matched Pair with Royer Shock Mounts',
#   'Oberheim Xpander XP-1 6 voice desktop version of the Matrix 12 US vers',
#   'Karaoke Machine',
#   'Roland HS-5 Session Mixer Digital Mixer',
#   'Behringer Powerplay HA6000 6-channel Headphone Mixing/Distribution Amp',
#   'Electro Harmonix Pulsar tremelo',
#   'Vox wah V847 pedal',
#   'Guitar Stand--Brand new',
#   'Eminence 12” Speaker 8 Ohms',
#   "Peavey 2x15  Bass/Guitar Cabinet 1990's",
#   'mpc live standalone',
#   'Vintage 70s Martin Blue Hard Case OM/OOO',
#   'Yamaha Weighted Keyboard',
#   'Jensen P12Q 12" Alnico 8 ohm speaker',
#   '(Trade) 1900s Gibson Mandolin Banjo MB JR',
#   '(Trade) Framus Texan Acoustic 1962',
#   '(Trade) Gibson LPJ Les Paul',
# ...
#   '2021-01-24 15:19',
#   '2021-01-24 15:19',
#   '2021-01-24 15:19',
#   '2021-01-24 15:18',
#   '2021-01-24 15:17',
#   '2021-01-24 15:17',
#   '2021-01-24 15:17',
#   '2021-01-24 15:17',
#   '2021-01-24 15:15',
#   '2021-01-24 15:15',
#   '2021-01-24 15:14',
#   '2021-01-24 15:13',
#   '2021-01-24 15:13',
#   '2021-01-24 15:13',
#   '2021-01-24 15:13',
#   '2021-01-24 15:13',
#   '2021-01-24 15:12',
#   '2021-01-24 15:11',
#   '2021-01-24 15:10',
#   '2021-01-24 15:10',
#   '2021-01-24 15:09',
#   '2021-01-24 15:09',
#   '2021-01-24 15:09',
#   '2021-01-24 15:05',
#   '2021-01-24 15:05',
#   '2021-01-24 15:05',
#   '2021-01-24 15:04',
#   '2021-01-24 15:04',
#   '2021-01-24 15:04',
#   '2021-01-24 15:01',
#   '2021-01-24 14:59',
#   '2021-01-24 14:59',
#   '2021-01-24 14:59',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:58',
#   '2021-01-24 14:56',
#   '2021-01-24 14:54',
#   '2021-01-24 14:53',
#   '2021-01-24 14:53',
#   '2021-01-24 14:53',
#   '2021-01-24 14:52',
#   '2021-01-24 14:52',
#   '2021-01-24 14:51',
#   '2021-01-24 14:50',
#   '2021-01-24 14:50',
#   '2021-01-24 14:49',
#   '2021-01-24 14:49',
#   '2021-01-24 14:47',
#   '2021-01-24 14:46',
#   '2021-01-24 14:45',
#   '2021-01-24 14:44',
#   '2021-01-24 14:44',
#   '2021-01-24 14:43',
#   '2021-01-24 14:43',
#   '2021-01-24 14:43',
#   '2021-01-24 14:42',
#   '2021-01-24 14:42',
#   '2021-01-24 14:41',
#   '2021-01-24 14:41',
#   '2021-01-24 14:40',
#   '2021-01-24 14:39',
#   '2021-01-24 14:39',
#   '2021-01-24 14:39',
#   '2021-01-24 14:37',
#   '2021-01-24 14:37',
#   '2021-01-24 14:36',
#   '2021-01-24 14:32',
#   '2021-01-24 14:32',
#   '2021-01-24 14:32',
#   '2021-01-24 14:32',
#   '2021-01-24 14:32',
#   '2021-01-24 14:32',
#   '2021-01-24 14:31',
#   '2021-01-24 14:30',
#   '2021-01-24 14:28',
#   '2021-01-24 14:26',
#   '2021-01-24 14:25',
#   '2021-01-24 14:24',
#   '2021-01-24 14:24',
#   '2021-01-24 14:23',
#   '2021-01-24 14:23',
#   '2021-01-24 14:22',
#   '2021-01-24 14:21',
#   '2021-01-24 14:21',
#   '2021-01-24 14:21',
#   '2021-01-24 14:21',
#   '2021-01-24 14:20',
#   '2021-01-24 14:19',
#   '2021-01-24 14:18',
#   '2021-01-24 14:18',
#   '2021-01-24 14:17',
#   '2021-01-24 14:16',
#   '2021-01-24 14:14',
#   '2021-01-24 14:14',
#   '2021-01-24 14:12',
#   '2021-01-24 14:10',
#   '2021-01-24 14:06',
#   '2021-01-24 14:05',
#   '2021-01-24 14:05',
#   '2021-01-24 14:04',
#   '2021-01-24 14:03',
#   '2021-01-24 14:01',
#   '2021-01-24 14:01',
#   '2021-01-24 14:01',
#   '2021-01-24 14:00',
#   '2021-01-24 14:00',
#   '2021-01-24 13:59',
#   '2021-01-24 13:59',
#   '2021-01-24 13:59',
#   '2021-01-24 13:59',
#   '2021-01-24 13:58',
#   '2021-01-24 13:58',
#   '2021-01-24 13:57',
#   '2021-01-24 13:57',
#   '2021-01-24 13:57',
#   '2021-01-24 13:55',
#   '2021-01-24 13:54',
#   '2021-01-24 13:53',
#   '2021-01-24 13:53',
#   '2021-01-24 13:53',
#   '2021-01-24 13:51',
#   '2021-01-24 13:49',
#   '2021-01-24 13:49',
#   '2021-01-24 13:49',
#   '2021-01-24 13:48',
#   '2021-01-24 13:48',
#   '2021-01-24 13:48',
#   '2021-01-24 13:47',
#   '2021-01-24 13:47',
#   '2021-01-24 13:47',
#   '2021-01-24 13:47',
#   '2021-01-24 13:46',
#   '2021-01-24 13:44',
#   '2021-01-24 13:41',
#   '2021-01-24 13:40',
#   '2021-01-24 13:39',
#   '2021-01-24 13:37',
#   '2021-01-24 13:35',
#   '2021-01-24 13:35',
#   '2021-01-24 13:34',
#   '2021-01-24 13:34',
#   '2021-01-24 13:34',
#   '2021-01-24 13:33',
#   '2021-01-24 13:32',
#   '2021-01-24 13:32',
#   '2021-01-24 13:31',
#   '2021-01-24 13:30',
#   '2021-01-24 13:30',
#   '2021-01-24 13:29',
#   '2021-01-24 13:29',
#   '2021-01-24 13:27',
#   '2021-01-24 13:26',
#   '2021-01-24 13:26',
#   '2021-01-24 13:25',
#   '2021-01-24 13:25',
#   '2021-01-24 13:25',
#   '2021-01-24 13:23',
#   '2021-01-24 13:21',
#   '2021-01-24 13:21',
#   '2021-01-24 13:20',
#   '2021-01-24 13:20',
#   '2021-01-24 13:20',
#   '2021-01-24 13:20',
#   '2021-01-24 13:19',
#   '2021-01-24 13:18',
#   '2021-01-24 13:18',
#   '2021-01-24 13:18',
#   '2021-01-24 13:18',
#   '2021-01-24 13:18',
#   '2021-01-24 13:17',
#   '2021-01-24 13:17',
#   '2021-01-24 13:17',
#   '2021-01-24 13:14',
#   '2021-01-24 13:14',
#   '2021-01-24 13:14',
#   '2021-01-24 13:14',
#   '2021-01-24 13:13',
#   '2021-01-24 13:12',
#   '2021-01-24 13:12',
#   '2021-01-24 13:12',
#   '2021-01-24 13:12',
#   '2021-01-24 13:09',
#   '2021-01-24 13:09',
#   '2021-01-24 13:08',
#   '2021-01-24 13:08',
#   '2021-01-24 13:07',
#   '2021-01-24 13:03',
#   '2021-01-24 13:03',
#   '2021-01-24 13:01',
#   '2021-01-24 13:01',
#   '2021-01-24 13:00',
#   '2021-01-24 12:58',
#   '2021-01-24 12:58',
#   '2021-01-24 12:58',
#   '2021-01-24 12:57',
#   '2021-01-24 12:57',
#   '2021-01-24 12:56',
#   '2021-01-24 12:55',
#   '2021-01-24 12:55',
#   '2021-01-24 12:54',
#   '2021-01-24 12:53',
#   '2021-01-24 12:53',
#   '2021-01-24 12:52',
#   '2021-01-24 12:52',
#   '2021-01-24 12:51',
#   '2021-01-24 12:50',
#   '2021-01-24 12:49',
#   '2021-01-24 12:47',
#   '2021-01-24 12:47',
#   '2021-01-24 12:45',
#   '2021-01-24 12:44',
#   '2021-01-24 12:44',
#   '2021-01-24 12:44',
#   '2021-01-24 12:44',
#   '2021-01-24 12:44',
#   '2021-01-24 12:43',
#   '2021-01-24 12:42',
#   '2021-01-24 12:42',
#   '2021-01-24 12:42',
#   '2021-01-24 12:42',
#   '2021-01-24 12:41',
#   '2021-01-24 12:41',
#   '2021-01-24 12:41',
#   '2021-01-24 12:41',
#   '2021-01-24 12:41',
#   '2021-01-24 12:41',
#   '2021-01-24 12:40',
#   '2021-01-24 12:40',
#   '2021-01-24 12:40',
#   '2021-01-24 12:40',
#   '2021-01-24 12:39',
#   '2021-01-24 12:39',
#   '2021-01-24 12:37',
#   '2021-01-24 12:36',
#   '2021-01-24 12:36',
#   '2021-01-24 12:35',
#   '2021-01-24 12:34',
#   '2021-01-24 12:31',
#   '2021-01-24 12:30',
#   '2021-01-24 12:29',
#   '2021-01-24 12:29',
#   '2021-01-24 12:28',
#   '2021-01-24 12:28',
#   '2021-01-24 12:26',
#   '2021-01-24 12:25',
#   '2021-01-24 12:25',
#   '2021-01-24 12:24',
#   '2021-01-24 12:23',
#   '2021-01-24 12:23',
#   '2021-01-24 12:21',
#   '2021-01-24 12:20',
#   '2021-01-24 12:20',
#   '2021-01-24 12:20',
#   '2021-01-24 12:20',
#   '2021-01-24 12:19',
#   '2021-01-24 12:19',
#   '2021-01-24 12:19',
#   '2021-01-24 12:19',
#   '2021-01-24 12:18',
#   '2021-01-24 12:18',
#   '2021-01-24 12:18',
#   '2021-01-24 12:17',
#   '2021-01-24 12:17',
#   '2021-01-24 12:16',
#   '2021-01-24 12:16',
#   '2021-01-24 12:16',
#   '2021-01-24 12:16',
#   '2021-01-24 12:15',
#   '2021-01-24 12:15',
#   '2021-01-24 12:14',
#   '2021-01-24 12:11',
#   '2021-01-24 12:09',
#   '2021-01-24 12:09',
#   '2021-01-24 12:09',
#   '2021-01-24 12:09',
#   '2021-01-24 12:09',
#   '2021-01-24 12:08',
#   '2021-01-24 12:08',
#   '2021-01-24 12:08',
#   '2021-01-24 12:07',
#   '2021-01-24 12:07',
#   '2021-01-24 12:06',
#   '2021-01-24 12:06',
#   '2021-01-24 12:06',
#   '2021-01-24 12:05',
#   '2021-01-24 12:04',
#   '2021-01-24 12:03',
#   '2021-01-24 12:03',
#   '2021-01-24 12:01',
#   '2021-01-24 12:00',
#   '2021-01-24 12:00',
#   '2021-01-24 12:00',
#   '2021-01-24 11:57',
#   '2021-01-24 11:57',
#   '2021-01-24 11:57',
#   '2021-01-24 11:57',
#   '2021-01-24 11:56',
#   '2021-01-24 11:52',
#   '2021-01-24 11:51',
#   '2021-01-24 11:50',
#   '2021-01-24 11:48',
#   '2021-01-24 11:48',
#   '2021-01-24 11:47',
#   '2021-01-24 11:47',
#   '2021-01-24 11:47',
#   '2021-01-24 11:47',
#   '2021-01-24 11:46',
#   '2021-01-24 11:44',
#   '2021-01-24 11:44',
#   '2021-01-24 11:43',
#   '2021-01-24 11:42',
#   '2021-01-24 11:39',
#   '2021-01-24 11:39',
#   '2021-01-24 11:38',
#   '2021-01-24 11:37',
#   '2021-01-24 11:37',
#   '2021-01-24 11:37',
#   '2021-01-24 11:37',
#   '2021-01-24 11:36',
#   '2021-01-24 11:36',
#   '2021-01-24 11:35',
#   '2021-01-24 11:29',
#   '2021-01-24 11:29',
#   '2021-01-24 11:29',
#   '2021-01-24 11:28',
#   '2021-01-24 11:28',
#   '2021-01-24 11:28',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:27',
#   '2021-01-24 11:26',
#   '2021-01-24 11:26',
#   '2021-01-24 11:26',
#   '2021-01-24 11:25',
#   '2021-01-24 11:25',
#   '2021-01-24 11:25',
#   '2021-01-24 11:24',
#   '2021-01-24 11:24',
#   '2021-01-24 11:22',
#   '2021-01-24 11:20',
#   '2021-01-24 11:20',
#   '2021-01-24 11:19',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:18',
#   '2021-01-24 11:17',
#   '2021-01-24 11:13',
#   '2021-01-24 11:11',
#   '2021-01-24 11:11',
#   '2021-01-24 11:10',
#   '2021-01-24 11:10',
#   '2021-01-24 11:09',
#   '2021-01-24 11:07',
#   '2021-01-24 11:05',
#   '2021-01-24 11:02',
#   '2021-01-24 11:01',
#   '2021-01-24 11:01',
#   '2021-01-24 11:01',
#   '2021-01-24 11:01',
#   '2021-01-24 10:59',
#   '2021-01-24 10:58',
#   '2021-01-24 10:58',
#   '2021-01-24 10:58',
#   '2021-01-24 10:58',
#   '2021-01-24 10:58',
#   '2021-01-24 10:58',
#   '2021-01-24 10:57',
#   '2021-01-24 10:57',
#   '2021-01-24 10:57',
#   '2021-01-24 10:56',
#   '2021-01-24 10:54',
#   '2021-01-24 10:53',
#   '2021-01-24 10:52',
#   '2021-01-24 10:51',
#   '2021-01-24 10:51',
#   '2021-01-24 10:50',
#   '2021-01-24 10:50',
#   '2021-01-24 10:49',
#   '2021-01-24 10:49',
#   '2021-01-24 10:48',
#   '2021-01-24 10:46',
#   '2021-01-24 10:45',
#   '2021-01-24 10:45',
#   '2021-01-24 10:45',
#   '2021-01-24 10:45',
#   '2021-01-24 10:43',
#   '2021-01-24 10:43',
#   '2021-01-24 10:42',
#   '2021-01-24 10:41',
#   '2021-01-24 10:41',
#   '2021-01-24 10:40',
#   '2021-01-24 10:39',
#   '2021-01-24 10:37',
#   '2021-01-24 10:36',
#   '2021-01-24 10:36',
#   '2021-01-24 10:36',
#   '2021-01-24 10:35',
#   '2021-01-24 10:31',
#   '2021-01-24 10:31',
#   '2021-01-24 10:31',
#   '2021-01-24 10:31',
#   '2021-01-24 10:31',
#   '2021-01-24 10:30',
#   '2021-01-24 10:30',
#   '2021-01-24 10:29',
#   '2021-01-24 10:29',
#   '2021-01-24 10:27',
#   '2021-01-24 10:25',
#   '2021-01-24 10:25',
#   '2021-01-24 10:24',
#   '2021-01-24 10:23',
#   '2021-01-24 10:23',
#   '2021-01-24 10:23',
#   '2021-01-24 10:22',
#   '2021-01-24 10:22',
#   '2021-01-24 10:22',
#   '2021-01-24 10:22',
#   '2021-01-24 10:21',
#   '2021-01-24 10:21',
#   '2021-01-24 10:21',
#   '2021-01-24 10:21',
#   '2021-01-24 10:21',
#   '2021-01-24 10:18',
#   '2021-01-24 10:17',
#   '2021-01-24 10:17',
#   '2021-01-24 10:15',
#   '2021-01-24 10:15',
#   '2021-01-24 10:14',
#   '2021-01-24 10:13',
#   '2021-01-24 10:12',
#   '2021-01-24 10:12',
#   '2021-01-24 10:11',
#   '2021-01-24 10:10',
#   '2021-01-24 10:09',
#   '2021-01-24 10:09',
#   '2021-01-24 10:07',
#   '2021-01-24 10:06',
#   '2021-01-24 10:06',
#   '2021-01-24 10:04',
#   '2021-01-24 10:04',
#   '2021-01-24 10:03',
#   '2021-01-24 10:03',
#   '2021-01-24 10:03',
#   '2021-01-24 10:03',
#   '2021-01-24 10:03',
#   '2021-01-24 10:02',
#   '2021-01-24 10:02',
#   '2021-01-24 10:02',
#   '2021-01-24 10:02',
#   '2021-01-24 10:02',
#   '2021-01-24 09:57',
#   '2021-01-24 09:57',
#   '2021-01-24 09:54',
#   '2021-01-24 09:53',
#   '2021-01-24 09:49',
#   '2021-01-24 09:49',
#   '2021-01-24 09:44',
#   '2021-01-24 09:41',
#   '2021-01-24 09:41',
#   '2021-01-24 09:40',
#   '2021-01-24 09:39',
#   '2021-01-24 09:39',
#   '2021-01-24 09:37',
#   '2021-01-24 09:37',
#   '2021-01-24 09:37',
#   '2021-01-24 09:37',
#   '2021-01-24 09:37',
#   '2021-01-24 09:37',
#   '2021-01-24 09:36',
#   '2021-01-24 09:36',
#   '2021-01-24 09:36',
#   '2021-01-24 09:36',
#   '2021-01-24 09:35',
#   '2021-01-24 09:35',
#   '2021-01-24 09:35',
#   '2021-01-24 09:35',
#   '2021-01-24 09:31',
#   '2021-01-24 09:30',
#   '2021-01-24 09:29',
#   '2021-01-24 09:26',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:25',
#   '2021-01-24 09:23',
#   '2021-01-24 09:22',
#   '2021-01-24 09:22',
#   '2021-01-24 09:21',
#   '2021-01-24 09:20',
#   '2021-01-24 09:16',
#   '2021-01-24 09:13',
#   '2021-01-24 09:13',
#   '2021-01-24 09:13',
#   '2021-01-24 09:12',
#   '2021-01-24 09:11',
#   '2021-01-24 09:11',
#   '2021-01-24 09:11',
#   '2021-01-24 09:11',
#   '2021-01-24 09:09',
#   '2021-01-24 09:08',
#   '2021-01-24 09:06',
#   '2021-01-24 09:06',
#   '2021-01-24 09:06',
#   '2021-01-24 09:06',
#   '2021-01-24 09:05',
#   '2021-01-24 09:04',
#   '2021-01-24 09:04',
#   '2021-01-24 09:03',
#   '2021-01-24 09:03',
#   '2021-01-24 09:03',
#   '2021-01-24 09:03',
#   '2021-01-24 09:02',
#   '2021-01-24 09:01',
#   '2021-01-24 09:00',
#   '2021-01-24 09:00',
#   '2021-01-24 09:00',
#   '2021-01-24 08:59',
#   '2021-01-24 08:58',
#   '2021-01-24 08:57',
#   '2021-01-24 08:56',
#   '2021-01-24 08:56',
#   '2021-01-24 08:56',
#   '2021-01-24 08:56',
#   '2021-01-24 08:56',
#   '2021-01-24 08:55',
#   '2021-01-24 08:55',
#   '2021-01-24 08:54',
#   '2021-01-24 08:53',
#   '2021-01-24 08:51',
#   '2021-01-24 08:48',
#   '2021-01-24 08:48',
#   '2021-01-24 08:48',
#   '2021-01-24 08:48',
#   '2021-01-24 08:47',
#   '2021-01-24 08:47',
#   '2021-01-24 08:45',
#   '2021-01-24 08:45',
#   '2021-01-24 08:45',
#   '2021-01-24 08:44',
#   '2021-01-24 08:43',
#   '2021-01-24 08:42',
#   '2021-01-24 08:42',
#   '2021-01-24 08:42',
#   '2021-01-24 08:41',
#   '2021-01-24 08:41',
#   '2021-01-24 08:40',
#   '2021-01-24 08:39',
#   '2021-01-24 08:31',
#   '2021-01-24 08:30',
#   '2021-01-24 08:40',
#   '2021-01-24 08:39',
#   '2021-01-24 08:31',
#   '2021-01-24 08:30',
#   '2021-01-24 08:29',
#   '2021-01-24 08:28',
#   '2021-01-24 08:28',
#   '2021-01-24 08:27',
#   '2021-01-24 08:26',
#   '2021-01-24 08:26',
#   '2021-01-24 08:24',
#   '2021-01-24 08:24',
#   '2021-01-24 08:23',
#   '2021-01-24 08:23',
#   '2021-01-24 08:22',
#   '2021-01-24 08:22',
#   '2021-01-24 08:22',
#   '2021-01-24 08:22',
#   '2021-01-24 08:22',
#   '2021-01-24 08:21',
#   '2021-01-24 08:21',
#   '2021-01-24 08:20',
#   '2021-01-24 08:20',
#   '2021-01-24 08:20',
#   '2021-01-24 08:19',
#   '2021-01-24 08:18',
#   '2021-01-24 08:18',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:17',
#   '2021-01-24 08:16',
#   '2021-01-24 08:13',
#   '2021-01-24 08:13',
#   '2021-01-24 08:13',
#   '2021-01-24 08:10',
#   '2021-01-24 08:10',
#   '2021-01-24 08:10',
#   '2021-01-24 08:09',
#   '2021-01-24 08:05',
#   '2021-01-24 08:05',
#   '2021-01-24 08:04',
#   '2021-01-24 08:03',
#   '2021-01-24 07:48',
#   '2021-01-24 07:47',
#   '2021-01-24 07:47',
#   '2021-01-24 07:47',
#   '2021-01-24 07:47',
#   '2021-01-24 07:46',
#   '2021-01-24 07:45',
#   '2021-01-24 07:44',
#   '2021-01-24 07:44',
#   '2021-01-24 07:43',
#   '2021-01-24 07:43',
#   '2021-01-24 07:43',
#   '2021-01-24 07:29',
#   '2021-01-24 07:29',
#   '2021-01-24 07:26',
#   '2021-01-24 07:25',
#   '2021-01-24 07:25',
#   '2021-01-24 07:25',
#   '2021-01-24 07:24',
#   '2021-01-24 07:20',
#   '2021-01-24 07:19',
#   '2021-01-24 07:19',
#   '2021-01-24 07:19',
#   '2021-01-24 07:19',
#   '2021-01-24 07:14',
#   '2021-01-24 07:02',
#   '2021-01-24 07:00',
#   '2021-01-24 06:58',
#   '2021-01-24 06:58',
#   '2021-01-24 06:57',
#   '2021-01-24 06:54',
#   '2021-01-24 06:53',
#   '2021-01-24 06:51',
#   '2021-01-24 06:51',
#   '2021-01-24 06:50',
#   '2021-01-24 06:50',
#   '2021-01-24 06:50',
#   '2021-01-24 06:45',
#   '2021-01-24 06:40',
#   '2021-01-24 06:29',
#   '2021-01-24 06:18',
#   '2021-01-24 06:10',
#   '2021-01-24 05:58',
#   '2021-01-24 05:27',
#   '2021-01-24 05:03',
#   '2021-01-24 05:01',
#   '2021-01-24 05:01',
#   '2021-01-24 05:00',
#   '2021-01-24 05:00',
#   '2021-01-24 05:00',
#   '2021-01-24 05:00',
#   '2021-01-24 04:52',
#   '2021-01-24 04:49',
#   '2021-01-24 04:46',
#   '2021-01-24 04:19',
#   '2021-01-24 03:31',
#   '2021-01-24 03:25',
#   '2021-01-24 03:08',
#   '2021-01-24 03:02',
#   '2021-01-24 02:50',
#   '2021-01-24 02:43',
#   '2021-01-24 02:35',
#   '2021-01-24 02:26',
#   '2021-01-24 02:24',
#   '2021-01-24 02:24',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:23',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:22',
#   '2021-01-24 02:14',
#   '2021-01-24 02:11',
#   '2021-01-24 01:50',
#   '2021-01-24 01:37',
#   '2021-01-24 01:28',
#   '2021-01-24 01:16',
#   '2021-01-24 01:16',
#   '2021-01-24 01:15',
#   '2021-01-24 01:11',
#   '2021-01-24 01:10',
#   '2021-01-24 01:08',
#   '2021-01-24 01:06',
#   '2021-01-24 01:05',
#   '2021-01-24 01:05',
#   '2021-01-24 01:05',
#   '2021-01-24 01:04',
#   '2021-01-24 01:04',
#   '2021-01-24 01:04',
#   '2021-01-24 00:56',
#   '2021-01-24 00:54',
#   '2021-01-24 00:42',
#   '2021-01-24 00:39',
#   '2021-01-24 00:39',
#   '2021-01-24 00:33',
#   '2021-01-24 00:30',
#   '2021-01-24 00:27',
#   '2021-01-24 00:25',
#   '2021-01-24 00:16',
#   '2021-01-24 00:15',
#   '2021-01-24 00:13',
#   '2021-01-24 00:12',
#   ...]}

# %% [markdown]
# Construct dataframe using dictionary

# %%
df_base = pd.DataFrame(base_dict)
df_base
# Out:
#        price  pics              hood  \
# 0       $950  True      (sebastopol)
# 1       $250  True      (sebastopol)
# 2       $350  True      (sebastopol)
# 3         $0  True       (los gatos)
# 4     $4,500  True       (los gatos)
# ...      ...   ...               ...
# 2875    $350  True            (Napa)
# 2876  $2,800  True      (santa rosa)
# 2877      $0  True      (santa rosa)
# 2878  $1,550  True          (gilroy)
# 2879    $600  True   (Scotts Valley)
#
#                                                   title         datetimes
# 0                   Ibanez MC200 Musician Series Guitar  2021-01-24 18:18
# 1                             Fender Performer 1000 amp  2021-01-24 18:17
# 2                                       Fender Champ 12  2021-01-24 18:17
# 3                                        Ovation Guitar  2021-01-24 18:15
# 4     !!! 2017 YULONG GUO ZIRICOTE CONCERT GUITAR - ...  2021-01-24 18:15
# ...                                                 ...               ...
# 2875                             Roland Percussion TD-3  2021-01-22 11:01
# 2876                               Kawai Piano for sale  2021-01-22 11:00
# 2877                                    Wurlitzer Piano  2021-01-22 11:00
# 2878                       Tyler Flip Top Bass Tube Amp  2021-01-22 10:58
# 2879  Hammered Dulcimer by Magical Strings, Vintage ...  2021-01-22 10:58
#
# [2880 rows x 5 columns]

# %% [markdown]
# Sort the results by the 'datetime' to order them by posting time.

# %%
df_base.sort_values('datetimes')
# Out:
#        price  pics              hood  \
# 2879    $600  True   (Scotts Valley)
# 2878  $1,550  True          (gilroy)
# 2876  $2,800  True      (santa rosa)
# 2877      $0  True      (santa rosa)
# 2875    $350  True            (Napa)
# ...      ...   ...               ...
# 4     $4,500  True       (los gatos)
# 3         $0  True       (los gatos)
# 2       $350  True      (sebastopol)
# 1       $250  True      (sebastopol)
# 0       $950  True      (sebastopol)
#
#                                                   title         datetimes
# 2879  Hammered Dulcimer by Magical Strings, Vintage ...  2021-01-22 10:58
# 2878                       Tyler Flip Top Bass Tube Amp  2021-01-22 10:58
# 2876                               Kawai Piano for sale  2021-01-22 11:00
# 2877                                    Wurlitzer Piano  2021-01-22 11:00
# 2875                             Roland Percussion TD-3  2021-01-22 11:01
# ...                                                 ...               ...
# 4     !!! 2017 YULONG GUO ZIRICOTE CONCERT GUITAR - ...  2021-01-24 18:15
# 3                                        Ovation Guitar  2021-01-24 18:15
# 2                                       Fender Champ 12  2021-01-24 18:17
# 1                             Fender Performer 1000 amp  2021-01-24 18:17
# 0                   Ibanez MC200 Musician Series Guitar  2021-01-24 18:18
#
# [2880 rows x 5 columns]

# %% [markdown]
# Convert to csv for import into regression notebook

# %%
df_base.to_csv('/Users/johnmetzger/Desktop/Coding/Project2/base_scrape.csv', index = False)
